# %%
import random

# Diccionario de algunas empresas del S&P 400 con sus respectivos tickers
empresas_sp400 = {
    "Alcoa": "AA",
    "American Airlines Group": "AAL",
    "AAON": "AAON",
    "Acadia Healthcare": "ACHC",
    "AECOM": "ACM",
    "Agree Realty": "ADC",
    "American Financial Group": "AFG",
    "AGCO": "AGCO",
    "Applied Industrial Technologies": "AIT",
    "ALLETE": "ALE",
    "Allegro MicroSystems": "ALGM",
    "Ally Financial": "ALLY",
    "Altair Engineering": "ALTR",
    "Autoliv": "ALV",
    "Antero Midstream": "AM",
    "Amedisys": "AMED",
    "Affiliated Managers Group": "AMG",
    "Ameriprise Financial": "AMP",
    "Ametek": "AME",
    "Amphenol": "APH",
    "Aptiv": "APTV",
    "Aramark": "ARMK",
    "Arrow Electronics": "ARW",
    "Assurant": "AIZ",
    "Atmos Energy": "ATO",
    "Autodesk": "ADSK",
    "Avery Dennison": "AVY",
    "Baker Hughes": "BKR",
    "Ball Corporation": "BALL",
    "Baxter International": "BAX",
    "Becton Dickinson": "BDX",
    "Best Buy": "BBY",
    "Bio-Rad Laboratories": "BIO",
    "Bio-Techne": "TECH",
    "Black Knight": "BKI",
    "BorgWarner": "BWA",
    "Boston Properties": "BXP",
    "Brighthouse Financial": "BHF",
    "Broadridge Financial Solutions": "BR",
    "Brown & Brown": "BRO",
    "C.H. Robinson Worldwide": "CHRW",
    "Cadence Design Systems": "CDNS",
    "Caesars Entertainment": "CZR",
    "Camden Property Trust": "CPT",
    "Campbell Soup": "CPB",
    "Capital One Financial": "COF",
    "Cardinal Health": "CAH",
    "CarMax": "KMX",
    "Carnival": "CCL",
    "Carrier Global": "CARR",
    "Catalent": "CTLT",
    "Cboe Global Markets": "CBOE",
    "CBRE Group": "CBRE",
    "CDW": "CDW",
    "Celanese": "CE",
    "Ceridian HCM Holding": "CDAY",
    "CF Industries": "CF",
    "Charles River Laboratories": "CRL",
    "Charles Schwab": "SCHW",
    "Charter Communications": "CHTR",
    "Chevron": "CVX",
    "Chipotle Mexican Grill": "CMG",
    "Chubb": "CB",
    "Church & Dwight": "CHD",
    "Cigna": "CI",
    "Cincinnati Financial": "CINF",
    "Cintas": "CTAS",
    "Cisco Systems": "CSCO",
    "Citigroup": "C",
    "Citizens Financial Group": "CFG",
    "Clorox": "CLX",
    "CME Group": "CME",
    "CMS Energy": "CMS",
    "Cognizant Technology Solutions": "CTSH",
    "Colgate-Palmolive": "CL",
    "Comcast": "CMCSA",
    "Comerica": "CMA",
    "Conagra Brands": "CAG",
    "ConocoPhillips": "COP",
    "Consolidated Edison": "ED",
    "Constellation Brands": "STZ",
    "Cooper Companies": "COO",
    "Copart": "CPRT",
    "Corning": "GLW",
    "Corteva": "CTVA",
    "CoStar Group": "CSGP",
    "Coterra Energy": "CTRA",
    "Crown Castle": "CCI",
    "CSX": "CSX",
    "Cummins": "CMI",
    "CVS Health": "CVS",
    "D.R. Horton": "DHI",
    "Danaher": "DHR",
    "Darden Restaurants": "DRI",
    "DaVita": "DVA",
    "Deere & Company": "DE",
    "Delta Air Lines": "DAL",
    "Dentsply Sirona": "XRAY",
    "Devon Energy": "DVN",
    "DexCom": "DXCM",
    "Diamondback Energy": "FANG",
    "Digital Realty Trust": "DLR",
    "Discover Financial Services": "DFS",
    "Discovery": "DISCA",
    "Dish Network": "DISH",
    "DocuSign": "DOCU",
    "Dollar General": "DG",
    "Dollar Tree": "DLTR",
    "Dominion Energy": "D",
    "Dover": "DOV",
    "Dow": "DOW",
    "DTE Energy": "DTE",
    "Duke Energy": "DUK",
    "DuPont de Nemours": "DD",
    "DXC Technology": "DXC",
    "Eastman Chemical": "EMN",
    "Eaton": "ETN",
    "eBay": "EBAY",
    "Ecolab": "ECL",
    "Edison International": "EIX",
    "Edwards Lifesciences": "EW",
    "Electronic Arts": "EA",
    "Emerson Electric": "EMR",
    "Enphase Energy": "ENPH",
    "Entergy": "ETR",
    "EOG Resources": "EOG",
    "EPAM Systems": "EPAM",
    "Equifax": "EFX",
    "Equinix": "EQIX",
    "Equity Residential": "EQR",
    "Essex Property Trust": "ESS",
    "Evergy": "EVRG",
    "Everest Re Group": "RE",
    "Evergy": "EVRG",
    "Eversource Energy": "ES",
    "Exelon": "EXC",
    "Expedia Group": "EXPE",
    "Expeditors International": "EXPD",
    "Extra Space Storage": "EXR",
    "Exxon Mobil": "XOM",
    "F5 Networks": "FFIV",
    "Fastenal": "FAST",
    "Federal Realty Investment Trust": "FRT",
    "FedEx": "FDX",
    "Fidelity National Information Services": "FIS",
    "Fifth Third Bancorp": "FITB",
    "First Republic Bank": "FRC",
    "First Solar": "FSLR",
    "FirstEnergy": "FE",
    "Fiserv": "FISV",
    "FleetCor Technologies": "FLT",
    "Lattice Semiconductor": "LSCC",
    "Lennox International": "LII",
    "Masimo": "MASI",
    "Manhattan Associates": "MANH",
    "MasTec": "MTZ",
    "Murphy Oil": "MUR",
    "Skechers": "SKX",
    "Tyler Technologies": "TYL",
    "XPO Logistics": "XPO"
}

# Seleccionar una empresa al azar
empresa, ticker = random.choice(list(empresas_sp400.items()))
print(f"Empresa seleccionada: {empresa} ({ticker})")
# Out:
# Empresa seleccionada: Dollar General (DG)
